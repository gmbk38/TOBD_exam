# %%
import numpy as np
# https://pythonworld.ru/numpy/2.html

a = np.array([1, 2, 3])
# a
# print(a[a > 2])
b = np.arange(12)
# b
b = b.reshape(3, 4)
# b
b[0][1]
# Out:
# 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Рандом
arr1 = np.random.randint(-5, 5, size = (10, 4))
arr2 = np.random.randint(-5, 5, size = (10, 4))
arr1[arr1 > arr2] *= 2
print(arr1)
# Out:
# [[ 6  4  2  6]
#  [ 1 -2 -1 -5]
#  [ 8 -5  0 -8]
#  [-1 -2  8  8]
#  [ 4  8 -4 -5]
#  [ 0  0 -2 -5]
#  [ 4  6 -4  6]
#  [ 6 -4  8  2]
#  [ 4 -4 -2 -1]
#  [-3 -2  2  6]]
